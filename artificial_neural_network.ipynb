# %% [markdown]
# # Artificial Neural Network

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Importing the dataset

# %%
dataset = pd.read_csv('Churn_Modelling.csv')

# %%
X = dataset.iloc[:,3:-1].values
y = dataset.iloc[:,-1].values

# %%
dataset.iloc[:,3:-1]
# Out:
#       CreditScore Geography  Gender  Age  ...  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0             619    France  Female   42  ...              1          1               1        101348.88
# 1             608     Spain  Female   41  ...              1          0               1        112542.58
# 2             502    France  Female   42  ...              3          1               0        113931.57
# 3             699    France  Female   39  ...              2          0               0         93826.63
# 4             850     Spain  Female   43  ...              1          1               1         79084.10
# ...           ...       ...     ...  ...  ...            ...        ...             ...              ...
# 9995          771    France    Male   39  ...              2          1               0         96270.64
# 9996          516    France    Male   35  ...              1          1               1        101699.77
# 9997          709    France  Female   36  ...              1          0               1         42085.58
# 9998          772   Germany    Male   42  ...              2          1               0         92888.52
# 9999          792    France  Female   28  ...              1          1               0         38190.78
#
# [10000 rows x 10 columns]

# %% [markdown]
# ### Encoding categorical data

# %% [markdown]
# Label Encoding the "Gender" column

# %%
le = LabelEncoder()
X[:,2] = le.fit_transform(X[:,2])
print(X)
# Out:
# [[619 'France' 0 ... 1 1 101348.88]
#  [608 'Spain' 0 ... 0 1 112542.58]
#  [502 'France' 0 ... 1 0 113931.57]
#  ...
#  [709 'France' 0 ... 0 1 42085.58]
#  [772 'Germany' 1 ... 1 0 92888.52]
#  [792 'France' 0 ... 1 0 38190.78]]

# %% [markdown]
# One Hot Encoding the "Geography" column

# %%
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1])], remainder="passthrough")
X = ct.fit_transform(X)
print(X)
# Out:
# [[1.0 0.0 0.0 ... 1 1 101348.88]
#  [0.0 0.0 1.0 ... 0 1 112542.58]
#  [1.0 0.0 0.0 ... 1 0 113931.57]
#  ...
#  [1.0 0.0 0.0 ... 0 1 42085.58]
#  [0.0 1.0 0.0 ... 1 0 92888.52]
#  [1.0 0.0 0.0 ... 1 0 38190.78]]

# %% [markdown]
# ### Splitting the dataset into the Training set and Test set

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ### Feature Scaling

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Part 2 - Building the ANN

# %% [markdown]
# ### Initializing the ANN

# %%
ann = Sequential()

# %% [markdown]
# ### Adding the input layer and the first hidden layer

# %%
ann.add(Dense(6, 'relu'))

# %% [markdown]
# ### Adding the second hidden layer

# %%
ann.add(Dense(6, 'relu'))

# %% [markdown]
# ### Adding the output layer

# %%
ann.add(Dense(1, 'sigmoid'))

# %% [markdown]
# ## Part 3 - Training the ANN

# %% [markdown]
# ### Compiling the ANN

# %%
ann.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Training the ANN on the Training set

# %%
ann.fit(X_train, y_train, batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4700 - accuracy: 0.7995
# Epoch 2/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4448 - accuracy: 0.8090
# Epoch 3/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4370 - accuracy: 0.8101
# Epoch 4/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4335 - accuracy: 0.8119
# Epoch 5/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4301 - accuracy: 0.8130
# Epoch 6/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4273 - accuracy: 0.8123
# Epoch 7/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4241 - accuracy: 0.8154
# Epoch 8/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4216 - accuracy: 0.8180
# Epoch 9/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4187 - accuracy: 0.8185
# Epoch 10/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4155 - accuracy: 0.8214
# Epoch 11/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4120 - accuracy: 0.8225
# Epoch 12/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4088 - accuracy: 0.8250
# Epoch 13/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4055 - accuracy: 0.8259
# Epoch 14/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4022 - accuracy: 0.8280
# Epoch 15/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3988 - accuracy: 0.8276
# Epoch 16/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3954 - accuracy: 0.8294
# Epoch 17/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3920 - accuracy: 0.8285
# Epoch 18/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3886 - accuracy: 0.8301
# Epoch 19/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3855 - accuracy: 0.8298
# Epoch 20/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3823 - accuracy: 0.8314
# Epoch 21/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3794 - accuracy: 0.8295
# Epoch 22/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3769 - accuracy: 0.8353
# Epoch 23/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3745 - accuracy: 0.8400
# Epoch 24/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3713 - accuracy: 0.8407
# Epoch 25/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3695 - accuracy: 0.8426
# Epoch 26/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3670 - accuracy: 0.8464
# Epoch 27/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3646 - accuracy: 0.8471
# Epoch 28/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8516
# Epoch 29/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3611 - accuracy: 0.8531
# Epoch 30/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3587 - accuracy: 0.8518
# Epoch 31/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3574 - accuracy: 0.8518
# Epoch 32/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3562 - accuracy: 0.8526
# Epoch 33/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3544 - accuracy: 0.8553
# Epoch 34/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3531 - accuracy: 0.8555
# Epoch 35/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3521 - accuracy: 0.8556
# Epoch 36/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3511 - accuracy: 0.8543
# Epoch 37/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3501 - accuracy: 0.8565
# Epoch 38/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3490 - accuracy: 0.8580
# Epoch 39/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3483 - accuracy: 0.8577
# Epoch 40/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3476 - accuracy: 0.8564
# Epoch 41/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3466 - accuracy: 0.8593
# Epoch 42/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3457 - accuracy: 0.8566
# Epoch 43/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3454 - accuracy: 0.8619
# Epoch 44/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3450 - accuracy: 0.8605
# Epoch 45/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3443 - accuracy: 0.8574
# Epoch 46/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3436 - accuracy: 0.8590
# Epoch 47/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3438 - accuracy: 0.8600
# Epoch 48/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3438 - accuracy: 0.8586
# Epoch 49/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3432 - accuracy: 0.8594
# Epoch 50/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3424 - accuracy: 0.8614
# Epoch 51/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3425 - accuracy: 0.8601
# Epoch 52/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3418 - accuracy: 0.8612
# Epoch 53/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3423 - accuracy: 0.8601
# Epoch 54/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3415 - accuracy: 0.8616
# Epoch 55/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3409 - accuracy: 0.8620
# Epoch 56/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3416 - accuracy: 0.8605
# Epoch 57/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3412 - accuracy: 0.8593
# Epoch 58/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3405 - accuracy: 0.8614
# Epoch 59/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3413 - accuracy: 0.8612
# Epoch 60/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3405 - accuracy: 0.8609
# Epoch 61/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3398 - accuracy: 0.8624
# Epoch 62/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3401 - accuracy: 0.8596
# Epoch 63/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3403 - accuracy: 0.8614
# Epoch 64/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3403 - accuracy: 0.8609
# Epoch 65/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3400 - accuracy: 0.8605
# Epoch 66/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3398 - accuracy: 0.8614
# Epoch 67/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3405 - accuracy: 0.8594
# Epoch 68/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3398 - accuracy: 0.8618
# Epoch 69/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3391 - accuracy: 0.8609
# Epoch 70/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3385 - accuracy: 0.8597
# Epoch 71/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3401 - accuracy: 0.8600
# Epoch 72/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3387 - accuracy: 0.8610
# Epoch 73/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3388 - accuracy: 0.8609
# Epoch 74/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3388 - accuracy: 0.8614
# Epoch 75/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3387 - accuracy: 0.8620
# Epoch 76/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3386 - accuracy: 0.8624
# Epoch 77/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3390 - accuracy: 0.8608
# Epoch 78/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3382 - accuracy: 0.8616
# Epoch 79/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3386 - accuracy: 0.8604
# Epoch 80/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3379 - accuracy: 0.8610
# Epoch 81/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3381 - accuracy: 0.8622
# Epoch 82/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3378 - accuracy: 0.8609
# Epoch 83/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3381 - accuracy: 0.8604
# Epoch 84/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3376 - accuracy: 0.8616
# Epoch 85/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3377 - accuracy: 0.8606
# Epoch 86/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3369 - accuracy: 0.8614
# Epoch 87/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3373 - accuracy: 0.8609
# Epoch 88/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3369 - accuracy: 0.8606
# Epoch 89/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3373 - accuracy: 0.8618
# Epoch 90/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3371 - accuracy: 0.8594
# Epoch 91/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3369 - accuracy: 0.8615
# Epoch 92/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3371 - accuracy: 0.8615
# Epoch 93/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3366 - accuracy: 0.8616
# Epoch 94/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3370 - accuracy: 0.8611
# Epoch 95/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3369 - accuracy: 0.8610
# Epoch 96/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3366 - accuracy: 0.8610
# Epoch 97/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3363 - accuracy: 0.8609
# Epoch 98/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3359 - accuracy: 0.8611
# Epoch 99/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3357 - accuracy: 0.8602
# Epoch 100/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3356 - accuracy: 0.8590

# %% [markdown]
# ## Part 4 - Making the predictions and evaluating the model

# %% [markdown]
# ### Predicting the result of a single observation

# %% [markdown]
# **Homework**
#
# Use our ANN model to predict if the customer with the following informations will leave the bank:
#
# Geography: France
#
# Credit Score: 600
#
# Gender: Male
#
# Age: 40 years old
#
# Tenure: 3 years
#
# Balance: \$ 60000
#
# Number of Products: 2
#
# Does this customer have a credit card ? Yes
#
# Is this customer an Active Member: Yes
#
# Estimated Salary: \$ 50000
#
# So, should we say goodbye to that customer ?

# %%
customer = np.array([600, 'France', 'Male', 40, 3, 60000, 2, 1, 1, 50000])
customer = customer.reshape(1, len(customer))
customer[0, 2] = le.transform([customer[0, 2]])[0]
customer = ct.transform(customer)
customer
# Out:
# array([['1.0', '0.0', '0.0', '600', '1', '40', '3', '60000', '2', '1',
#         '1', '50000']], dtype='<U32')

# %%
customer = sc.transform(customer)
customer
# Out:
# array([[ 0.98560362, -0.5698444 , -0.57369368, -0.52111599,  0.91601335,
#          0.10961719, -0.68538967, -0.2569057 ,  0.8095029 ,  0.64259497,
#          0.9687384 , -0.87203322]])

# %%
pred = ann.predict(customer)
pred
# Out:
# 1/1 [==============================] - 0s 23ms/step
# array([[0.03237496]], dtype=float32)

# %% [markdown]
# **Solution**

# %% [markdown]
# Therefore, our ANN model predicts that this customer stays in the bank!
#
# **Important note 1:** Notice that the values of the features were all input in a double pair of square brackets. That's because the "predict" method always expects a 2D array as the format of its inputs. And putting our values into a double pair of square brackets makes the input exactly a 2D array.
#
# **Important note 2:** Notice also that the "France" country was not input as a string in the last column but as "1, 0, 0" in the first three columns. That's because of course the predict method expects the one-hot-encoded values of the state, and as we see in the first row of the matrix of features X, "France" was encoded as "1, 0, 0". And be careful to include these values in the first three columns, because the dummy variables are always created in the first columns.

# %% [markdown]
# ### Predicting the Test set results

# %%
y_pred = ann.predict(X_test)
y_pred = y_pred.reshape(len(y_pred), 1)
y_pred = y_pred >= 0.5
compare = pd.concat([pd.DataFrame(y_pred, columns=["Prediction"]), pd.DataFrame(y_test.reshape(len(y_test), 1), columns=["Original"])], 1)
compare.iloc[:30,:]
# Out:
# 63/63 [==============================] - 0s 4ms/step
# <ipython-input-109-5214820e23e9>:4: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   compare = pd.concat([pd.DataFrame(y_pred, columns=["Prediction"]), pd.DataFrame(y_test.reshape(len(y_test), 1), columns=["Original"])], 1)
#     Prediction  Original
# 0        False         0
# 1        False         1
# 2        False         0
# 3        False         0
# 4        False         0
# 5         True         1
# 6        False         0
# 7        False         0
# 8        False         1
# 9         True         1
# 10       False         0
# 11       False         0
# 12       False         0
# 13       False         0
# 14        True         1
# 15       False         1
# 16       False         0
# 17       False         0
# 18       False         0
# 19       False         0
# 20        True         0
# 21       False         0
# 22       False         0
# 23       False         0
# 24       False         0
# 25       False         0
# 26       False         0
# 27       False         0
# 28       False         0
# 29       False         0

# %% [markdown]
# ### Making the Confusion Matrix

# %%
cm = confusion_matrix(y_pred, y_test)
acc = accuracy_score(y_pred, y_test)
print(cm)
print(f'Accuracy Score: {acc*100}%')
# Out:
# [[1532  215]
#  [  63  190]]
# Accuracy Score: 86.1%
